# %% [markdown]
# # Practice Interview
#
# ## Objective
#
# _*The partner assignment aims to provide participants with the opportunity to practice coding in an interview context. You will analyze your partner's Assignment 1. Moreover, code reviews are common practice in a software development team. This assignment should give you a taste of the code review process.*_
#
# ## Group Size
#
# Each group should have 2 people. You will be assigned a partner
#
# ## Parts:
# - Part 1: Complete 1 of 3 questions
# - Part 2: Review your partner's Assignment 1 submission
# - Part 3: Perform code review of your partner's assignment 1 by answering the questions below
# - Part 3: Reflect on Assignment 1 and Assignment 2
#
# ## Part 1:
#
# _*You will be assigned one of three problems based of your first name. Enter your first name, in all lower case, execute the code below, and that will tell you your assigned problem. Include the output as part of your submission (do not clear the output). The problems are based-off problems from Leetcode.*_

# %%
import hashlib

def hash_to_range(input_string: str) -> int:
     hash_object = hashlib.sha256(input_string.encode())
     hash_int = int(hash_object.hexdigest(), 16)
     return (hash_int % 3) + 1
input_string = "glenn"
result = hash_to_range(input_string)
print(result)
# Out:
# 1

# %% [markdown]
# <details>
#   <summary>Question 1</summary>
#
#   # Question One: Check Duplicates in Tree
#
#   Given the `root` of a binary tree, check whether it is contains a duplicate value. If a duplicate exists, return the duplicate value. If there are multiple duplicates, return the one with the closest distance to the root. If no duplicate exists, return -1.
#
#   ## Examples
#
#   ### Example 1
#
#   ![](./images/q1_ex1.png)
#
#   Input: `root = [1, 2, 2, 3, 5, 6, 7]` *What traversal method is this?*
#
#   Output: 2
#
#   ### Example 2
#
#   ![](./images/q1_ex2.png)
#
#   Input: `root = [1, 10, 2, 3, 10, 12, 12]`
#
#   Output: 10
#
#   ### Example 3
#
#   ![](./images/q1_ex3.png)
#
#   Input: `root = [10, 9, 8, 7]`
#
#   Output: -1
#
# </details>
#
# #### Starter Code for Question 1

# %%
# Definition for a binary tree node.
# class TreeNode(object):
#     def __init__(self, val = 0, left = None, right = None):
#         self.val = val
#         self.left = left
#         self.right = right

from collections import deque

def is_duplicate(root: TreeNode) -> int:
    if not root:
        return -1
    
    # Use BFS to traverse level by level (closest to root first)
    queue = deque([root])
    seen = set()
    
    while queue:
        node = queue.popleft()
        
        # If we've seen this value before, it's a duplicate
        if node.val in seen:
            return node.val
        
        # Add current value to seen set
        seen.add(node.val)
        
        # Add children to queue for next level
        if node.left:
            queue.append(node.left)
        if node.right:
            queue.append(node.right)
    
    # No duplicates found
    return -1

# %% [markdown]
# <details>
#   <summary>Question 2</summary>
#
#   # Question Two: Path to Leaves
#
#   Given the `root` of a binary tree, return all root to leaf paths in any order.
#
#   ## Examples
#
#   ### Example 1
#
#   ![](./images/q1_ex1.png)
#
#   Input: `root = [1, 2, 2, 3, 5, 6, 7]` *What traversal method is this?*
#
#   Output: [[1, 2, 3], [1, 2, 5], [1, 2, 6], [1, 2, 7]]
#
#   ### Example 2
#
#   ![](./images/q1_ex3.png)
#
#   Input: `root = [10, 9, 7, 8]`
#
#   Output: [[10, 7], [10, 9, 8]]
#
# </details>
#
# #### Starter Code for Question 2

# %%
# Definition for a binary tree node.
# class TreeNode(object):
#     def __init__(self, val = 0, left = None, right = None):
#         self.val = val
#         self.left = left
#         self.right = right
def bt_path(root: TreeNode) -> List[List[int]]:
  # TODO

# %% [markdown]
# <details>
#   <summary>Question 3</summary>
#
#   # Question Three: Missing Number in Range
#
#   You are given a list containing `n` integers in the range `[0, n]`. Return a list of numbers that are missing from the range `[0, n]` of the array. If there is no missing number, return -1. Note, all the integers in the list may not be unique.
#
#   ## Examples
#
#   ### Example 1
#
#   Input: `lst = [0, 2]`
#
#   Output: [1]
#
#   ### Example 2
#
#   Input: `lst = [5, 0, 1]`
#
#   Output: [2, 3, 4]
#
#   ### Example 3
#
#   Input: `lst = [6, 8, 2, 3, 5, 7, 0, 1, 10]`
#
#   Output: [4, 9]
#
# </details>
#
# #### Starter Code for Question 3

# %%
def missing_num(nums: List) -> int:
  # TODO

# %% [markdown]
# ## Part 2:
#
# You and your partner must share each other's Assignment 1 submission.

# %% [markdown]
# ## Part 3:
#
# Create a Jupyter Notebook, create 6 of the following headings, and complete the following for your partner's assignment 1:
#
# -   Paraphrase the problem in your own words.

# %% [markdown]
# Doren was assigned problem 3. This problem asked the asignee to take a list of integers and move every zero to the end of the list, while ensuring the order of the rest of the numbers remains preserved.

# %% [markdown]
# -   Create 1 new example that demonstrates you understand the problem. Trace/walkthrough 1 example that your partner made and explain it.

# %% [markdown]
# Doren provided the following example:
# Input: nums = [0, 8, 2, 0, 1, 6, 0] →
# Output: [8, 2, 1, 6, 0, 0, 0]
#
# In Doren's example, the zeroes are no longer in the first and fourth place. The 8, 2, 1 and 6 remain unbroken in their order while the zeroes which previously preceeded them have moved to the end.

# %% [markdown]
# New example:
# Input: nums = [0, 0, 1, 0, -2, 3, 0, 4]
# Output: [1, -2, 3, 4, 0, 0, 0, 0]

# %% [markdown]
# -   Copy the solution your partner wrote.

# %% [markdown]
# Version 4
# '''
# from typing import List
#
# def move_zeros_to_end(nums: List[int]) -> List[int]:
#     # TODO
#     insert_pos = 0
#     for i in range(len(nums)):
#         if nums[i] != 0:
#             nums[insert_pos], nums[i] = nums[i], nums[insert_pos]
#             insert_pos += 1
#     return nums
# nums = [0, 1, 0, 3, 12]
# move_zeros_to_end(nums)
# [1, 3, 12, 0, 0]
# nums = [4, 0, 5, 0, 0, 6]
# move_zeros_to_end(nums)
# [4, 5, 6, 0, 0, 0]
# Explain why your solution works
# # Your answer here
#
# Start by initializing a pointer called insert_pos at index 0. This marks the position where the next non-zero element should be placed. Then, iterate through the entire list. For each element, if it is not zero, swap it with the element at insert_pos. After the swap, increment insert_pos by 1 to prepare for the next non-zero element. This process continues until all non-zero elements have been moved to the front, preserving their original order, while all zeros are shifted to the back. By working directly the list, there is no need to create a new variable and help space complexity.

# %% [markdown]
# -   Explain why their solution works in your own words.

# %% [markdown]
# In Doren's solution, insert_pos points to where the next non-zero should be placed; scanning left-to-right and swapping each non-zero into insert_pos (then incrementing it) preserves the non-zero elements’ original order. Because every non-zero is moved forward, the leftover positions become zeros, so all zeros end up at the end of the list in-place without extra space.

# %% [markdown]
# -   Explain the problem’s time and space complexity in your own words.

# %% [markdown]
# Doren uses an in-place two‑pointer approach where insert_pos marks the position for the next non‑zero; therefore each non‑zero is swapped forward to insert_pos and insert_pos is incremented. Because the algorithm makes a single pass over n elements with only O(1) work per element, the time complexity is O(n). It uses only a few variables and performs swaps in the original list, so the extra space complexity is O(1).

# %% [markdown]
# -   Critique your partner's solution, including explanation, and if there is anything that should be adjusted.

# %% [markdown]
# Doren’s solution is correct, fast, and uses no extra space.
#
# What’s good:
#
# It does exactly what it should: moves all zeros to the end and keeps the other numbers in the same order.
# It scans the list once, so it’s fast: O(n) time.
# It doesn’t make a whole new list, so it uses only a few extra variables: O(1) space.
#
# Things to fix or improve:
#
# Comment left as “# TODO” is misleading — remove it or replace with a real short comment.
# The explanation in the notebook has a small wrong sentence about complexity: it says “n is the number of characters in the str” — that’s an error. It should say “n is the number of elements in the list.”
#
# What to add to the notebook
#
# Replace “# TODO” with a short comment or the docstring above.
# Fix the complexity explanation to say “n is the number of items in the list.”
# Add 3 quick tests: empty list, all zeros, no zeros. Example: [], [0,0,0], [1,2,3].
# Add one sentence that warns the function changes the original list (in case a user expects a new list).
# Two‑sentence explanation (cleaned up) insert_pos marks where the next non-zero should go; scan left to right and swap each non-zero into insert_pos, then increase insert_pos. After the pass, all non-zero values are at the front in the same order and all zeros are pushed to the end, and this is done in-place with O(n) time and O(1) extra space.

# %% [markdown]
# ## Part 4:
#
# Please write a 200 word reflection documenting your process from assignment 1, and your presentation and review experience with your partner at the bottom of the Jupyter Notebook under a new heading "Reflection." Again, export this Notebook as pdf.

# %% [markdown]
# ### Reflection

# %% [markdown]
# Doren’s assigned problem (Move All Zeros to End) and my problem (First Duplicate in List) both require linear-time thinking and handling of element order, but they differ in approach and data structures. My first-duplicate solutions considered nested loops and a hash-set optimization; that emphasizes detecting earlier occurrences with extra bookkeeping.
#
# Doren’s solution used an in-place two-pointer swap to preserve order while minimizing space. Both solutions are O(n) time in their optimized forms, but the first-duplicate set-based version uses O(n) extra space while Doren’s uses O(1).
#
# Overall, comparing analyzing these use cases/problems highlights trade-offs between simplicity, space usage, and whether functions mutate input, and shows practical choices for interview-style coding problems. These questions aremeant to have us, as students, demonstrate an understanding of different solutions and their and trade-offs.

# %% [markdown]
# ## Evaluation Criteria
#
# We are looking for the similar points as Assignment 1
#
# -   Problem is accurately stated
#
# -   New example is correct and easily understandable
#
# -   Correctness, time, and space complexity of the coding solution
#
# -   Clarity in explaining why the solution works, its time and space complexity
#
# -   Quality of critique of your partner's assignment, if necessary

# %% [markdown]
# ## Submission Information
#
# 🚨 **Please review our [Assignment Submission Guide](https://github.com/UofT-DSI/onboarding/blob/main/onboarding_documents/submissions.md)** 🚨 for detailed instructions on how to format, branch, and submit your work. Following these guidelines is crucial for your submissions to be evaluated correctly.
#
# ### Submission Parameters:
# * Submission Due Date: `HH:MM AM/PM - DD/MM/YYYY`
# * The branch name for your repo should be: `assignment-2`
# * What to submit for this assignment:
#     * This Jupyter Notebook (assignment_2.ipynb) should be populated and should be the only change in your pull request.
# * What the pull request link should look like for this assignment: `https://github.com/<your_github_username>/algorithms_and_data_structures/pull/<pr_id>`
#     * Open a private window in your browser. Copy and paste the link to your pull request into the address bar. Make sure you can see your pull request properly. This helps the technical facilitator and learning support staff review your submission easily.
#
# Checklist:
# - [ ] Created a branch with the correct naming convention.
# - [ ] Ensured that the repository is public.
# - [ ] Reviewed the PR description guidelines and adhered to them.
# - [ ] Verify that the link is accessible in a private browser window.
#
# If you encounter any difficulties or have questions, please don't hesitate to reach out to our team via our Slack at `#cohort-6-help`. Our Technical Facilitators and Learning Support staff are here to help you navigate any challenges.
